# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the data - csv file
df=pd.read_csv("bmi.csv")
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
# DATA PREPROCESSING AND CLEANING

# %%
#description of the dataset
df.describe() #tuple indicated by() -- immutable 
# finds the continuous columns
# Out:
#            Height      Weight       Index
# count  500.000000  500.000000  500.000000
# mean   169.944000  106.000000    3.748000
# std     16.375261   32.382607    1.355053
# min    140.000000   50.000000    0.000000
# 25%    156.000000   80.000000    3.000000
# 50%    170.500000  106.000000    4.000000
# 75%    184.000000  136.000000    5.000000
# max    199.000000  160.000000    5.000000

# %%
df.describe #returns the dataset
# Out:
# <bound method NDFrame.describe of      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]>

# %%
df.info() #information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  500 non-null    object
#  1   Height  500 non-null    int64
#  2   Weight  500 non-null    int64
#  3   Index   500 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 15.8+ KB

# %%
df.shape #shape denotes the no.of rows and columns of the dataset
# Out:
# (500, 4)

# %%
df.columns #returns the column names
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %%
df.dtypes #returns the datatype of the columns
# Out:
# Gender    object
# Height     int64
# Weight     int64
# Index      int64
# dtype: object

# %%
df.duplicated() #checks for duplicated or repeated values and return boolean as result
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
df[df.duplicated()] #doesnt means
# Out:
#      Gender  Height  Weight  Index
# 187  Female     182      84      3
# 310    Male     171     147      5
# 327  Female     167      85      4
# 355    Male     174      90      3
# 365    Male     141      80      5
# 381    Male     191      62      1
# 382    Male     177     117      4
# 395  Female     164      71      3
# 400  Female     195     104      3
# 462    Male     179      56      1
# 482  Female     142      86      5

# %%
df.nunique() #no.of unique entries in each column
# Out:
# Gender      2
# Height     60
# Weight    110
# Index       6
# dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Female    255
# Male      245
# Name: Gender, dtype: int64

# %%
df.Height.value_counts()
# Out:
# 188    15
# 179    14
# 187    14
# 168    13
# 178    13
# 184    12
# 182    12
# 172    12
# 181    11
# 185    11
# 150    11
# 183    11
# 153    10
# 157    10
# 195    10
# 165    10
# 154    10
# 169    10
# 162     9
# 161     9
# 166     9
# 186     9
# 159     9
# 167     9
# 190     9
# 164     9
# 177     9
# 142     9
# 146     9
# 145     9
# 180     8
# 141     8
# 174     8
# 152     8
# 171     8
# 140     8
# 163     8
# 151     8
# 147     7
# 191     7
# 197     7
# 160     7
# 176     7
# 170     6
# 156     6
# 192     6
# 155     6
# 196     6
# 198     5
# 194     5
# 148     5
# 193     5
# 158     5
# 189     5
# 149     5
# 144     5
# 175     4
# 173     4
# 199     3
# 143     3
# Name: Height, dtype: int64

# %%
df.Weight.value_counts()
# Out:
# 80     9
# 104    9
# 50     9
# 96     8
# 70     8
#       ..
# 91     1
# 63     1
# 93     1
# 134    1
# 53     1
# Name: Weight, Length: 110, dtype: int64

# %%
df.Index.value_counts()
# Out:
# 5    198
# 4    130
# 2     69
# 3     68
# 1     22
# 0     13
# Name: Index, dtype: int64

# %%
#to check the foreign entries
for i in df.columns:
    print(i)
    print(list(df[i].unique()))
# Out:
# Gender
# ['Male', 'Female']
# Height
# [174, 189, 185, 195, 149, 147, 154, 169, 159, 192, 155, 191, 153, 157, 140, 144, 172, 151, 190, 187, 163, 179, 178, 160, 197, 171, 175, 161, 182, 188, 181, 168, 176, 196, 164, 143, 141, 193, 194, 180, 165, 166, 186, 198, 145, 183, 177, 170, 142, 199, 150, 146, 148, 184, 158, 167, 156, 162, 173, 152]
# Weight
# [96, 87, 110, 104, 61, 92, 111, 90, 103, 81, 80, 101, 51, 79, 107, 129, 145, 139, 149, 97, 67, 64, 95, 62, 159, 152, 121, 52, 65, 131, 153, 132, 114, 120, 108, 56, 118, 126, 76, 122, 72, 135, 54, 105, 116, 89, 127, 70, 88, 143, 83, 158, 59, 82, 136, 117, 75, 100, 154, 140, 123, 50, 141, 119, 156, 69, 155, 160, 106, 66, 157, 60, 57, 138, 115, 151, 150, 147, 124, 85, 125, 146, 98, 84, 102, 99, 78, 109, 94, 74, 73, 134, 137, 144, 93, 86, 130, 58, 148, 68, 71, 63, 91, 142, 133, 77, 128, 112, 55, 53]
# Index
# [4, 2, 3, 5, 1, 0]

# %%
#to check null values or N/A or NaN values
df.isna().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# Index     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# Index     0
# dtype: int64

# %%
#if dropvalues present - drop those null values
df.dropna()
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
df.dropna(inplace=True #drops the value if Null value == true

# %%
#eda - exploratory data analysis

# %%
df.columns=[x.lower()for x in df.columns]
df.columns
# Out:
# Index(['gender', 'height', 'weight', 'index'], dtype='object')

# %%
categoryCol = ['gender']
continuousCol = ['height', 'weight']
target = ['index']

# %%
#univariate 
df['gender'].value_counts().plot(kind='pie')
plt.legend(title = "Gender")

# %%
df.height.hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
for i in continuousCol:
    print(i)
    df[i].hist()
    plt.show()
# Out:
# height
# weight

# %%
df['index'].value_counts().plot(kind='pie')
plt.legend()

# %%
plt.boxplot(df['height'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x290720bd310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x290720bd8b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x290720bd0a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x290720bde50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x290720cb160>],
#  'means': []}

# %%
plt.boxplot(df['weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29072122430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x290721229d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29072122160>],
#  'medians': [<matplotlib.lines.Line2D at 0x29072122f70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2907212f280>],
#  'means': []}

# %%
#bivariate 
import seaborn as sns

# %%
sns.boxplot(x=df['height'],y=df['index'])
# Out:
# <AxesSubplot:xlabel='height', ylabel='index'>

# %%
sns.boxplot(x=df['weight'],y=df['index'])
# Out:
# <AxesSubplot:xlabel='weight', ylabel='index'>

# %%
for categoryColumn in categoryCol:
    print(df.groupby([categoryColumn,'index']).agg(indexcount=('index','count')))
    sns.countplot(x=categoryColumn,hue='index',data=df)
    plt.show()
# Out:
#               indexcount
# gender index
# Female 0               7
#        1               7
#        2              41
#        3              36
#        4              71
#        5              93
# Male   0               6
#        1              15
#        2              28
#        3              32
#        4              59
#        5             105

# %%
sns.pairplot(df, hue='index',height = 4)

# %%
#label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df[categoryCol +target] = df[categoryCol + target].apply(LabelEncoder().fit_transform)

# %%
df[['gender','index']]
# Out:
#      gender  index
# 0         1      4
# 1         1      2
# 2         0      4
# 3         0      3
# 4         1      3
# ..      ...    ...
# 495       0      5
# 496       0      4
# 497       0      5
# 498       1      5
# 499       1      5
#
# [500 rows x 2 columns]

# %%
df[categoryCol +target] = df[categoryCol + target].apply(LabelEncoder().fit_transform)
print(df[categoryCol+target])
# Out:
#      gender  index
# 0         1      4
# 1         1      2
# 2         0      4
# 3         0      3
# 4         1      3
# ..      ...    ...
# 495       0      5
# 496       0      4
# 497       0      5
# 498       1      5
# 499       1      5
#
# [500 rows x 2 columns]
